# %%
data = ""
with open("counts.txt", "r") as file:
    data = file.read()
data = list(map(lambda x: (int(x.split(" ")[1]), x.split(" ")[0]), data.strip().split("\n")))

# %%
data.sort()
print(data)
# print(sum(data)/len(data))
# Out:
# [(160, '11'), (169, '132'), (177, '6'), (184, '318'), (186, '10'), (193, '319'), (203, '252'), (211, '301'), (220, '14'), (220, '91'), (221, '315'), (221, '317'), (228, '34'), (237, '291'), (237, '305'), (237, '36'), (237, '94'), (245, '13'), (245, '224'), (245, '289'), (245, '299'), (245, '92'), (254, '133'), (254, '16'), (254, '165'), (254, '178'), (254, '84'), (263, '125'), (263, '290'), (263, '304'), (263, '31'), (271, '12'), (271, '128'), (271, '134'), (271, '284'), (271, '300'), (277, '187'), (280, '143'), (280, '176'), (280, '18'), (280, '265'), (280, '267'), (280, '268'), (280, '285'), (280, '312'), (288, '120'), (288, '230'), (288, '262'), (288, '303'), (288, '322'), (288, '5'), (288, '54'), (288, '7'), (288, '93'), (297, '222'), (297, '226'), (297, '229'), (297, '264'), (297, '302'), (297, '306'), (297, '32'), (305, '228'), (305, '275'), (305, '286'), (305, '321'), (305, '33'), (305, '56'), (305, '98'), (314, '126'), (314, '141'), (314, '142'), (314, '307'), (314, '95'), (3
# ...

# %%
x = [(1,2), (5,3), (2, 4)]
x.sort()
x
# Out:
# [(1, 2), (2, 4), (5, 3)]

# %%
# min_index = list(map(lambda x: x[1], data[:5]))
# max_index = list(map(lambda x: x[1], data[-5:]))
# mid_index = list(map(lambda x: x[1], data[162:167]))

min_index = data[:5]
max_index = data[-5:]
mid_index = data[162:167]

# %%
min_index
# Out:
# [(160, '11'), (169, '132'), (177, '6'), (184, '318'), (186, '10')]

# %%
mid_index
# Out:
# [(408, '9'), (416, '109'), (416, '153'), (416, '182'), (416, '206')]

# %%
max_index
# Out:
# [(1355, '191'), (1380, '194'), (1449, '309'), (1457, '193'), (1978, '255')]
